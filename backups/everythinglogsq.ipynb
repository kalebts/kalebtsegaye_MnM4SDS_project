# %% [markdown]
# # Table of Contents
#
# [Imports](#Imports)
#
# [Playground](#Playground)
#
# [Spotify Functions](#Spotify-Functions)
#
# [Songkick Functions](#Songkick-Functions)
#
# [Analysis Functions](#Analysis-Functions)
#
# [Analysis](#Analysis)

# %% [markdown]
# # Imports
#
# [Back to top](#Table-of-Contents)

# %%
#import necessary libraries
import requests
import json
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import re
import spotipy
import base64
import teetool as tt
from collections import Counter
import libpysal
from pysal.model import spreg
from libpysal.weights import Queen, Rook, KNN, Kernel
import pysal
from pysal.explore import esda
from pysal.viz.splot import esda as esdaplot
import cenpy
# import movingpandas as mpd
import datetime
from datetime import date
from spotipy.oauth2 import SpotifyClientCredentials
from census import Census
import censusgeocode
import us
import folium
import statsmodels
import statsmodels.formula.api as sm
import numpy
import statistics
import itertools as it
import math

api_key = "fCnCRQ1S6LDAS7zQ"
client_id = 'f5a0fe76389c42c0b85c832f1de66cf7'
client_secret = 'e9d4fc0874f345b2b636a6e307384bb7'
census_key = '684a12c6b65d2fe14bdf6d8354da8fe3aff08d70'
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

cen = Census(census_key)


world = gpd.read_file('Countries_WGS84/Countries_WGS84.shp') #open file
states_shp = gpd.read_file('states_21basic/states.shp') #open file

s2 = states_shp[['geometry', 'STATE_ABBR']]
s2.columns = ['geometry', 'name']

w2 = world[['geometry', 'CNTRY_NAME']]
w2.columns = ['geometry', 'name']

ws = w2.append(s2)

print(ws)


#maybe remove festivals - songkick
# maybe market - spotify
# Out:
#                                              geometry                 name
# 0   POLYGON ((-69.8822326660156 12.4111099243165, ...                Aruba
# 1   (POLYGON ((-61.7388916015625 17.5405540466309,...  Antigua and Barbuda
# 2   POLYGON ((61.2765579223633 35.6072463989258, 6...          Afghanistan
# 3   POLYGON ((-5.15213489532459 30.1804695129396, ...              Algeria
# 4   (POLYGON ((45.0258293151855 41.0305480957031, ...           Azerbaijan
# ..                                                ...                  ...
# 46  POLYGON ((-94.46169128436209 34.19676535931296...                   AR
# 47  (POLYGON ((-93.70752428365972 30.2395783556275...                   LA
# 48  (POLYGON ((-80.7856622716253 28.78519435427305...                   FL
# 49  (POLYGON ((-88.49752727880752 48.1737953723300...                   MI
# 50  (POLYGON ((-161.3337853466416 58.7332483821643...                   AK
#
# [302 rows x 2 columns]

# %% [markdown]
# # Playground
#
# [Back to top](#Table-of-Contents)

# %% [markdown]
# # Spotify Functions
#
# [Back to top](#Table-of-Contents)

# %%
# spotify function definitions

# given a name/id or genre, will provide a list of 
# artists that exist in relation and also are within the follower limit

# custom function used to sort by num of shared genres
def custom_sort(x):
    return x[2]

query_count = 0

# handles counting the genres for related artists
def ra_help(artid, genres, followers, lessthan):
    global query_count
#     print(followers)
    alist = []
    if query_count < 10:
        query_count += 1
        for a in sp.artist_related_artists(artid)['artists']:
#             print(a)
            gc = 0
            if (followers == -1):
                for g in a['genres']:    
                    if g in genres:
                        gc += 1
                if gc > 0 and ([item for item in alist if item[1] == a['id']] == []):
                    alist.append((a['name'], a['id'], gc, a['followers']['total']))
            else:
                if (lessthan == True):
#                     print(a)
                    if (a['followers']['total'] < followers):
                        for g in a['genres']:    
                            if g in genres:
                                gc += 1
                        if gc > 0 and ([item for item in alist if item[1] == a['id']] == []):
                            alist.append((a['name'], a['id'], gc, a['followers']['total']))
                elif (lessthan == False):
                    if (a['followers']['total'] >= followers):
                        for g in a['genres']:    
                            if g in genres:
                                gc += 1
                        if gc > 0 and ([item for item in alist if item[1] == a['id']] == []):
                            alist.append((a['name'], a['id'], gc, a['followers']['total']))
                
        return sorted(alist, key = custom_sort, reverse = True)
                    
# used to faciliate recursive calls - 
# allows me to find the related artists in each level of separation from the root
# before moving on to the root artist
def ra_rec(lst, genres, followers, lessthan):
    global query_count
    lst2 = []
    query_count += 1
    for a in lst:
        if query_count < 10:
            lst2+=(ra_help(a[1], genres, followers, lessthan))
#         print("ra_rec ra_help" + str(query_count))
    if query_count < 10:
        lst2 += (ra_rec((sorted(lst2, key = custom_sort)), genres, followers, lessthan))    
    
    return sorted(lst2, key = custom_sort, reverse = True)

def related_artists(artname='', artid='', genre='', followers=-1, lessthan = True, llen = -1):
    if (artname == '' and artid == '' and genre == ''):
        print('please include name, id, or genre')
        return
    else:
        global query_count
        query_count = 0
        alist = []
        if (artname != ''):
            se = sp.search(q = artname, limit = 1, type = 'artist')
            query_count += 1
            print("related_artists search " + str(query_count))
            if (se['artists']['total'] > 0):
                artist = se['artists']['items'][0]
                artid = artist['id']
                genres = artist['genres']
        elif (artid != ''):
            artist = sp.artist(artid)
            genres = artist['genres']
            
#         print(artist)
        
        for a in sp.artist_related_artists(artid)['artists']:
            genres+=a['genres']
            
#         print(genres)

        lst = ra_help(artid, genres, followers, lessthan)
#         print(lst)
        query_count += 1
        print("related_artists ra_help " + str(query_count))
                
        if query_count < 10:
            lst+=(ra_rec(lst, genres, followers, lessthan))
          
        print(len(lst))
        
        print(len(sorted(list(set(lst)), key = custom_sort)))
    
    if llen > 0:
        return sorted(list(set(lst)), key = custom_sort, reverse = True)[0:llen]
    else:
        return sorted(list(set(lst)), key = custom_sort, reverse = True)


# related_artists(artname = 'berhana', followers = 75000)

# %% [markdown]
# # Songkick Functions
#
# [Back to top](#Table-of-Contents)

# %%
# function definitions

# takes json string from songkick for an artist and makes points based on the results
def make_points(json_str, artist):
    df = pd.DataFrame(
    {'Artist': [],
     'Venue': [],
     'City': [],
     'State/Province': [],
     'Country': [],
     'Longitude': [],
     'Latitude': []})

    i = 0
    
    if (json_str['resultsPage']['totalEntries'] != 0):
        for p in json_str['resultsPage']['results']['event']:
            #     print(p['popularity'])
            venue = p['venue']['displayName']
            lng = p['location']['lng']
            lat = p['location']['lat']
            city = p['location']['city']
            state = 'N/A'
            csplit = city.split(',')
            country = csplit[1]
        
            if (len(csplit) == 3):
                if not ('Washington' == csplit[0] and 'DC' == csplit[1]):
                    city = csplit[0]
                    state = csplit[1]
                    country = csplit[2]
                else:
                    city = csplit[0] + ', ' + csplit[1]
                    state = 'N/A'
                    country = csplit[2].replace(' ', '')
        
            df.loc[i] = [artist] + [venue] + [city] + [state] + [country] + [lat] +[lng]

            i+=1
        #convert to gdf to plot
        gdf = gpd.GeoDataFrame(
            df, geometry=[Point(x, y) for y, x in zip(df['Longitude'], df['Latitude'])])

        gdf2 = gdf
        gdf2 = gdf2.drop(list(range(1, len(gdf))))
        gdf3 = gdf
        gdf3 = gdf3.drop(list(range(0, len(gdf)-1)))
    
        return(gdf, gdf2, gdf3)
    else:
        return -1
    
def find_tour(json_str, artist, tr = 7, cutoff_yr = 2):
    df = pd.DataFrame(
    {'Artist': [],
     'Venue': [],
     'City': [],
     'State/Province': [],
     'Country': [],
     'Longitude': [],
     'Latitude': [],
     't': []})

    i = 0
    
    arr = []
    
    if (json_str['resultsPage']['totalEntries'] != 0):
        for p in json_str['resultsPage']['results']['event']:
            if 'US' in p['location']['city']:
                venue = p['venue']['displayName']
                lng = p['location']['lng']
                lat = p['location']['lat']
                city = p['location']['city']
                state = 'N/A'
                csplit = city.split(',')
                country = csplit[1]
        
                if (len(csplit) == 3):
                    if not ('Washington' == csplit[0] and 'DC' == csplit[1]):
                        city = csplit[0]
                        state = csplit[1]
                        country = csplit[2]
                    else:
                        city = csplit[0] + ', ' + csplit[1]
                        state = city
                        country = csplit[2].replace(' ', '')
                    df.loc[i] = [artist] + [venue] + [city] + [state] + [country] + [lat] + [lng] + [p['start']['date']]
            
                i+=1
            
                if (len(p['location']['city'].split(',')) == 3):
                    d = p['start']['date'].split('-')
                    arr.append(date(int(d[0]), int(d[1]), int(d[2])))
    else:
        return -1
    
    l = [0,0]
    first = 0
    last = 0
    for i in range(len(arr)-1):
        if (arr[i] != -1 and arr[i+1] != -1):
            if (((arr[i] - arr[i+1]).days > tr) or (i == len(arr)-2)):
                last = i
                if (last-first > l[1] - l[0]):
                    l = [first, last]
                first = i+1
        else:
            last = i
            if (last-first > l[1] - l[0]):
                l = [first, last]
            first = i+1
            
#     print(l)
    
    df2 = pd.DataFrame(
    {'Artist': [],
     'Venue': [],
     'City': [],
     'State/Province': [],
     'Country': [],
     'Longitude': [],
     'Latitude': [],
     't': []})
    
    if (len(df) > 0):
        for i in range(l[0], l[1]+1):
            df2.loc[i] = df.loc[i]
        
        #convert to gdf to plot
        gdf = gpd.GeoDataFrame(
                df2, geometry=[Point(x, y) for y, x in zip(df2['Longitude'], df2['Latitude'])])

        return gdf
    else:
        return -1

# plots singular tour path for artist
def run_plot(req, aname):
    gdfs = make_points(req.json(), aname)

    points_gdf = gdfs[0]
    print(points_gdf)
    start_gdf = gdfs[1]
    stop_gdf = gdfs[2]

    #current us basemap
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

    # fig, ax = plt.subplots(figsize=(15,15))
    ax = world[world.continent == 'North America'].plot(
#     ax = world.plot(
        color='white', edgecolor='black')

    ax.set_xlim(-130, -65)
    ax.set_ylim(24, 50)

    # We can now plot our ``GeoDataFrame``.
    points_gdf.plot(ax=ax, color='blue')

    start_gdf.plot(ax=ax, color='green')
    stop_gdf.plot(ax=ax, color='red')

    points = []

    linedf = pd.DataFrame(
        {'Line': []})

    for i in range(len(points_gdf)):
        points.append(points_gdf.iloc[i].loc["geometry"])

    line = LineString(points)

    def plot_line(ax, ob):
        x, y = ob.xy
        ax.plot(x, y, color='grey', alpha=0.7, linewidth=1, solid_capstyle='round', zorder=2)

    plot_line(ax, line)

    plt.tight_layout()

    plt.show()
    
# used to find the artist id on songkick
def get_artist_id(artist_name):
    json_str = requests.get("https://api.songkick.com/api/3.0/search/artists.json?apikey=" + api_key + "&query=" + artist_name).json()
    return (str(json_str['resultsPage']['results']['artist'][0]['id']) if json_str['resultsPage']['totalEntries'] != 0 else -1)

# function for interface for taking input
def req_input():
    print("Welcome")
    while (True):
        past = True
        is_venue = True
        
        cmd = input("Venue search (0) or event search (1)?")
        
        if (cmd == 1):
            is_venue = False
            
        if (is_venue == False):
            cmd = input("Past events (0), upcoming events (1): ")
        
            if (cmd == 1):
                past = False
            
            cmd = input("Please type the parameters: [artist_name, min_date, max_date.] Separate with commas."
                       + "\nIf no input, just add a comma and skip.\n")
        
            if (cmd == 'quit'):
                return
        
            cs = cmd.split(',')
            an = get_artist_id(cs[0].replace(' ', '+')) if not (cs[0]+' ').isspace() else print('need artist!')
            if (cs[0]+' ').isspace():
                continue
            mind = "&min_date=" + cs[1].replace(' ', '') if (re.search("\d{4}-\d{2}-\d{2}", cs[1])) else ''
            maxd = "&max_date=" + cs[2].replace(' ', '') if (re.search("\d{4}-\d{2}-\d{2}", cs[2])) else ''
            
            if (past == True):
                r = requests.get("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key 
                              + mind + maxd)
                run_plot(r, cs[0])
            else:
                r = requests.get("https://api.songkick.com/api/3.0/events.json?apikey="+ api_key 
                    + an + loc + mind + maxd)
                print(r.json())
                run_plot(r, cs[0])
        else:
            cmd = input("Past venues (0), upcoming venues (1): ")
        
            if (cmd == 1):
                past = False
            
        cmd = input("Please type the parameters: [artist_name, min_date, max_date.] Separate with commas."
                   + "\nIf no input, just add a comma and skip.\n")
        
        if (cmd == 'quit'):
            return
        
        cs = cmd.split(',')
        an = get_artist_id(cs[0].replace(' ', '+')) if not (cs[0]+' ').isspace() else print('need artist!')
        if (cs[0]+' ').isspace():
            continue
        mind = "&min_date=" + cs[1].replace(' ', '') if (re.search("\d{4}-\d{2}-\d{2}", cs[1])) else ''
        maxd = "&max_date=" + cs[2].replace(' ', '') if (re.search("\d{4}-\d{2}-\d{2}", cs[2])) else ''
        
        if (past == True):
            r = requests.get("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key 
                              + mind + maxd)
            run_plot(r, cs[0])
        else:
            r = requests.get("https://api.songkick.com/api/3.0/events.json?apikey="+ api_key 
                + an + loc + mind + maxd)
            print(r.json())
            run_plot(r, cs[0])
              

    
# req = requests.get("https://api.songkick.com/api/3.0/events.json?apikey=fCnCRQ1S6LDAS7zQ&artist_name=young+thug&min_date=2019-10-01&max_date=2019-11-01")

# req = requests.get("https://api.songkick.com/api/3.0/events.json?apikey=fCnCRQ1S6LDAS7zQ&artist_name=travis+scott&min_date=2018-01-01&max_date=2022-11-01")

# print(get_artist_id('travis+scott'))

# print("https://api.songkick.com/api/3.0/artists/"+ get_artist_id('travis+scott') + "/gigography.json?apikey=fCnCRQ1S6LDAS7zQ")

# print(req.text)

# %% [markdown]
# # Analysis Functions
#
# [Back to top](#Table-of-Contents)

# %%
# this function generates many related artists, returns most recent events for each one, 
def compile_points(names = [], followers = -1, event_num=8):
    if not (names == []):
            print('yo')
            artists = []
            if followers == -1:   
                for n in names:
                    artists += related_artists(artname = n, llen = 10)
            else:
                for n in names:
                    artists += related_artists(artname = n, llen = 10, followers = followers)

#             print('llen')
#             print(artists)
            nl = []
            for a in artists:
                nl.append(a[0])
            
            nl = list(set(nl))
            
            gl = []
            
            for a in nl:
                an = get_artist_id(a.replace(' ', '+')) if not (a[0]+' ').isspace() else print('need artist!')
    
                if an != -1:
                    req = requests.get("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key + '&per_page='+str(event_num)+'&order=desc')
#             print("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key + '&per_page=20&order=desc')
                    gdfs = make_points(req.json(), a)
                    if gdfs != -1:
                        gl.append(gdfs[0])
                
            return gl
    else:
        return -1

# gdfs = compile_points(names = ['pat app', 'supakaine'], followers = 50000)
# gdf = compile_points(['pat app'])
# gdf2 = compile_points(['supakaine'])

# %%
def basic_stats(gdfs, state = ''):    
    rdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    
    # basic stats
    venues = {}
    cities = {}
    countries_states = {}
    
    for index, row in rdf.iterrows():
        if row[1] != 'Unknown venue':
            print(row)
            if row[1] not in venues:
                venues[row[1]] = 1
            else:
                venues[row[1]] += 1
          
        if row[3] != 'N/A':
            if (row[2] + ', ' + row[3][1:]) not in cities:
                cities[(row[2] + ', ' + row[3][1:])] = 1
            else:
                cities[(row[2] + ', ' + row[3][1:])] += 1
        else:
            if (row[2] + ', ' + row[4]) not in cities:
                cities[(row[2] + ', ' + row[4][1:])] = 1
            else:
                cities[(row[2] + ', ' + row[4][1:])] += 1
            
        if row[3] != 'N/A':
            if (row[3][1:]) not in countries_states:
                countries_states[row[3][1:]] = 1
            else:
                countries_states[row[3][1:]] += 1

        
        if (row[4][1:]) not in countries_states:
            countries_states[row[4][1:]] = 1
        else:
            countries_states[row[4][1:]] += 1
            
    print('Top 5 venues:')
    top = Counter(venues)
    for i in top.most_common(5):
        print(i[0] + ' ' + str(i[1]))
        
    print('\nTop 5 cities:')
    top = Counter(cities)
    for i in top.most_common(5):
        print(i[0] + ' ' + str(i[1]))
        
    print('\nTop 5 countries:')
    top = Counter(countries_states)
    for i in top.most_common(5):
        print(i[0] + ' ' + str(i[1]))
        
    return(venues)
        
    # end basic stats    

def autocorr(gdfs, state = ''):
    rdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

    plt.figure(figsize=(10, 12))

    world = ws
    
    showcount = []
    
    for index, row in world.iterrows():
        if row[1] == 'United States':
            c = 'US'            
        elif row[1] == 'United Kingdom':
            c = 'UK'
        else:
            c = row[1]
#             print(c)
        
        if c in countries_states:
            showcount.append(countries_states[c])
        else:
            showcount.append(0)
        
    world["ShowCount"] = showcount #make new column

    for index, row in ws.iterrows():
        if row[1] == 'United States':
            world.drop(index, inplace=True)
    
    fig, ax = plt.subplots(figsize=(15,15)) #plot
    world.plot("ShowCount", ax=ax)
    plt.tight_layout()
    plt.show()
    
    # morans i

    qW = Queen.from_dataframe(world)
    
    qW.silent_island_warning = True

    qW.transform = 'r'

    #moran
    moran_sc = esda.moran.Moran(world[['ShowCount']], qW)

    #lisa
    lisa_sc = esda.Moran_Local(world["ShowCount"], qW)

    print(str(moran_sc.I) + ", " + str(moran_sc.p_sim))
    
    from pysal.viz.splot import esda as esdaplot
    esdaplot.plot_local_autocorrelation(lisa_sc, world, "ShowCount")

    plt.show()    
    
def analyze(gdfs, state = ''):
    rdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    basic_stats(gdfs)
    autocorr(gdfs)
    
def venue_count(gdfs, usonly = True):    
    rdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
    
    venues = {}
    
    if (usonly == True):
        for index, row in rdf.iterrows():
            if row[1] != 'Unknown venue':
                if (row[4].replace(' ', '') == 'US'): 
                    if row[1] not in venues.keys():
                        venues[row[1]] = [(row[5],row[6], row[2], row[3].replace(' ', '')), 1]
                    else:
                        venues[row[1]][1] += 1
        
    return(venues)


def get_tracts(vens):
    tracts = {}
    
    for k,v in vens.items():
#         print(v)
        x = float(v[0][1])
        y = float(v[0][0])
        r = ''
        try:
            r = censusgeocode.coordinates(x=x, y=y)
        except:
            print('censusgeocode error')
            continue
        
        try:
            r = r['2010 Census Blocks']
            st = r[0]['STATE']
            co = r[0]['COUNTY']
            tr = r[0]['TRACT']
            print(st + co + tr)
            b = cen.acs5.state_county_tract('B02001_002E,B02001_001E,B01002_001E,B19013_001E', st, co, tr)
            b2 = cen.acs5.state_county_tract('B02001_003E', st, co, tr)

            ftr = st + co + tr
            if (ftr not in tracts.keys()):
                tracts[ftr] = {'Non-white population percentage': -1,
                'Black population percentage': -1,
                'Median age': -1,
                'Median household income': -1,
#                 'Nonfamily households percentage': -1,
                'Count': -1}
                tracts[ftr]['Non-white population percentage'] = (1 - b[0]['B02001_002E']/b[0]['B02001_001E'])
                tracts[ftr]['Black population percentage'] = math.log(b2[0]['B02001_003E']/b[0]['B02001_001E'])
                tracts[ftr]['Median age'] = b[0]['B01002_001E']**2
                tracts[ftr]['Median household income'] = b[0]['B19013_001E']**2
#                 tracts[ftr]['Nonfamily households percentage'] = b2[0]['B11001_007E']/b2[0]['B11001_001E']
                tracts[ftr]['Count'] = v[1]
            else:
#                 print(tracts)
                tracts[ftr]['Count'] += v[1]
        except KeyboardInterrupt:
            raise
        except:
            print('some other error')
            
        # b = c.acs5.state_place('B25034_010E', states.CA.fips, 'Los Angeles')
#         print(b)

    return tracts

        
# analyze(gdfs)

# %%
def tract_reg(tr, demo='non-white'):
#     print(tr)
    height = len(tr)
    width = len(next(iter(tr.values())))
    for k,vl in tr.items():
        v = list(vl.values())
        for i in range(width):
            if v[i] == -1:
#                 print(i)
                height = height - 1
                break

    print(height)
    print(width)

    arrr = [[0 for x in range(width-1)] for y in range(height)] 

    c = []

    i = 0
    for k,vl in tr.items():
        v = list(vl.values())

        br = False
        for j in range(width-1):
            if v[j] == -1:
#                 print(j)
                br = True

        if (br==True):
#             print('yo')
            continue

        c.append(v[width-1])
        for j in range(width-1):
            arrr[i][j] = v[j]
        i+=1
    
    if (demo == 'black'):
        for row in arrr:
            del row[0]
    else:
        for row in arrr:
            del row[1]
            
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    X = numpy.array(arrr)
    vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
    print(vif)
        
#     print(arrr)
    return statsmodels.regression.linear_model.OLS(c, arrr).fit().summary()

# %%
def tract_stats(names, followers, demo):
    points = compile_points(names, followers = followers)
    tracts = get_tracts(venue_count(points))
    print(tract_reg(tracts, demo=demo))
    
    
tract_stats(names = ['pat app', 'supakaine'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 56
# 28
# related_artists search 1
# related_artists ra_help 3
# 110
# 78
# 36061003700
# 06001983200
# 06037212900
# 42101037600
# 39035141100
# 06037700501
# 13121003000
# 48201310100
# censusgeocode error
# 06037199000
# 36047030500
# censusgeocode error
# censusgeocode error
# 48201310100
# 13121000500
# 37119004900
# 17031061100
# 09003500100
# 48113020400
# censusgeocode error
# 48201100000
# 48113020400
# 53033004900
# 06067001300
# 06075020100
# 48113020400
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 53033008600
# 17031330100
# 06037207710
# 06073005300
# 06001402800
# 53033005301
# 08031002403
# censusgeocode error
# 17031221500
# 09009361402
# 51760030200
# 36061015300
# 36061008300
# 04013421202
# 06037195803
# 36061003100
# 37119000700
# 36047031500
# 36
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.763
# Model:                            OLS   Adj. R-squared (uncentered):              0.742
# Method:                 Least Squares   F-statistic:                              35.48
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    1.95e-10
# Time:                        23:49:13   Log-Likelihood:                         -37.366
# No. Observations:                  36   AIC:                                      80.73
# Df Residuals:                      33   BIC:                                      85.48
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2193      0.075     -2.916      0.006      -0.372      -0.066
# x2             0.0006      0.000      3.762      0.001       0.000       0.001
# x3         -7.758e-12   1.47e-11     -0.528      0.601   -3.77e-11    2.21e-11
# ==============================================================================
# Omnibus:                       17.919   Durbin-Watson:                   2.448
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.714
# Skew:                           1.530   Prob(JB):                     1.93e-05
# Kurtosis:                       5.262   Cond. No.                     6.78e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.78e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# def tract_stats(names, followers):

# tract_reg(tracts, demo='black')
    
    
# tract_stats(names = ['pat app', 'supakaine'], followers = 50000)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# # print(arrr)
# print(len(c))
# statsmodels.regression.linear_model.OLS(c, arrr).fit().summary()
# # print(statsmodels.)
X = numpy.array(arrr)
# # print(X)
vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
print(vif)
# # statsmodels.regression.linear_model.OLS(c, arrr).fit().summary()

# %%
# req_input()

#travis scott, 2018-10-31, 2018-12-01

# %%
# se = sp.search(q = 'genre:%22southern%20hip%20hop%22', type = 'album', market = 'US')

#         for a in sp.artist_related_artists(artid)['artists']:

# this function generates many related artists, returns most recent events for each one, 
def compile_tours(names = [], followers = -1, lessthan = True):
    if (names != [] and isinstance(names, list)):
            print('yo')
            artists = []
            if followers == -1:   
                for n in names:
                    artists += related_artists(artname = n, llen = 10)
            else:
                for n in names:
                    artists += related_artists(artname = n, llen = 10, followers = followers)

#             print('llen')
            print(artists)
            nl = []
            for a in artists:
                nl.append(a[0])
            
            nl = list(set(nl))
            
            print(len(nl))
            
            gl = []
            
            for a in nl:
                an = get_artist_id(a.replace(' ', '+')) if not (a[0]+' ').isspace() else print('need artist!')
    
                if an != -1:
                    req = requests.get("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key + '&per_page=50&order=desc')
#             print("https://api.songkick.com/api/3.0/artists/"+ an +"/gigography.json?apikey="+ api_key + '&per_page=20&order=desc')
                    g = find_tour(req.json(), a)
                    if g is not int:
                        gl.append(g)
            
            return gl
    else:
        return -1

# %%
def plot_all_tours(ts):
    m = folium.Map(location=[40, -95], zoom_start=4)

    colors = ['blue', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen']

    cc = -1

    for x in ts:
        if not isinstance(x, int) and len(x) != 0:
            if (cc!=len(colors)-1):
                cc += 1
            else:
                cc = 0
    
            points = []

            for i, row in x.iterrows():
                tooltip = 'Artist: '+ str(row[0]) + '- City: ' + str(row[2]) + ', ' + str(row[3])

                points.append((row[5], row[6]))

                folium.Circle([row[5], row[6]], radius = 8, color = colors[cc], fill = True, weight = 5, popup='<i></i>', tooltip=tooltip).add_to(m)

            folium.PolyLine(points, color=colors[cc], weight=2.5, opacity=1).add_to(m)
            
    return m

# %%
def optimal_path(ts):
    avg = 0
    maxm = 0
    cities = {}
    #     print(len(list))
    for t in ts:

        if not isinstance(t, int):
            for i,row in t.iterrows():
                city = str(row[2]) + ', ' + str(row[3]) + ', ' + str(row[4])
                if city not in cities.keys():
                    cities[city] = [(row[5], row[6]), 1]
                else:
                    cities[city][1] += 1

    lst = sorted(cities.items(), key = 
             lambda kv:(kv[1][1], kv[0]), reverse=True)

    maxm = lst[0][1][1]
    sl = []
    for i in lst:
        avg += i[1][1]
        sl.append(i[1][1])

    sd = statistics.stdev(sl)

    avg = avg/len(lst)

    green = []
    lg = []
    yellow = []
    red = []

    for i in lst:
        count = i[1][1]
        if (count >= avg + sd*1.5):
            green.append(i[1][0])
        elif (count >= avg):
            lg.append(i[1][0])
        elif (count >= avg - sd/2):
            yellow.append(i[1][0])
        else:
            red.append(i[1][0])

    final_points = green


    def dist(x,y):
        return math.hypot(y[0]-x[0],y[1]-x[1])

    paths = [ p for p in it.permutations(final_points) ]
    path_distances = [ sum(map(lambda x: dist(x[0],x[1]),zip(p[:-1],p[1:]))) for p in paths ]
    min_index = numpy.argmin(path_distances)

    print(str(paths[min_index]) + ' ' + str(path_distances[min_index]))

    final_path = []

    for i in paths[min_index]:
        final_path.append(i)

    print(final_path)

    def add_fp(fp, l, std):
        i = 0
        while (i < len(l)):
            if (l[i] not in fp):
                for j in range(len(fp)-1):
                    if ((dist(fp[j], l[i]) + dist(l[i], fp[j+1])) < (std*dist(fp[j], fp[j+1]))):
                        if (l[i] not in fp):
                            fp.insert(j+1, l[i])
                            print(l[i])
                            i = -1
                        continue
            i+=1

        return fp

    final_path = add_fp(final_path, lg, 1.5)
    final_path = add_fp(final_path, yellow, 1.2)
    final_path = add_fp(final_path, red, 1.05)

    print(final_path)

    m = folium.Map(location=[40, -95], zoom_start=4)

    count = 0
    for k, v in lst:
        color = ''
        if (v[0] in green):
            count+=1
            color = 'green'
        elif (v[0] in lg):
            count+=1
            color = 'lightgreen'
        elif (v[0] in yellow):
            count+=1
            color = 'yellow'
        elif (v[0] in red):
            count+=1
            color = 'red'
        else:
            print('oops')
                
        tooltip = 'City: ' + str(k) + ' - Count: ' + str(v[1])
        folium.Circle([v[0][0], v[0][1]], radius = 8, color = color, fill = True, weight = 5, popup='<i></i>', tooltip=tooltip).add_to(m)

    folium.PolyLine(final_path, color='blue', weight=1, opacity=1.5).add_to(m)
  
    return m
    
# optimal_path(ts)

# %% [markdown]
# # Analysis
#
# [Back to top](#Table-of-Contents)

# %% [markdown]
# Three genres: Hip-hop, Rock, Country and Four regions each: Midwest, East, West, South
#
# Each pair of genre/region uses four or five artists that are from that area and under that genre.
#
# These artists are used as the root artists to find related artists to get a sample of performance data.
#
# Under each genre/region pair, there is:
# * a regression done on the tracts the venues are found in
# * plot of each artist's longest tour path from their past 50 shows
# * a plot of the optimal path an artist would take with color coded points to signify the quality of each stop
#     * Green: Shows > average + 1.5*sd
#     * light green: Shows > average
#     * Yellow: Shows > average - sd/2
#     * red: everything else

# %% [markdown]
# ## Hip-hop

# %% [markdown]
# x1: (Black population)/(Total Population)
#
# x2: Median Age
#
# x3: Median Household Income

# %% [markdown]
# ### Midwest (https://djbooth.net/features/2015-11-03-next-up-in-the-midwest)

# %%
tract_stats(names = ['pat app', 'supakaine', 'Kweku Collins', 'IshDARR'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 56
# 28
# related_artists search 1
# related_artists ra_help 3
# 110
# 78
# related_artists search 1
# related_artists ra_help 3
# 65
# 18
# related_artists search 1
# related_artists ra_help 3
# 67
# 23
# 25017353101
# some other error
# censusgeocode error
# 39049003200
# 29095015800
# 08031003701
# censusgeocode error
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 53033008600
# 17031330100
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 37183052602
# censusgeocode error
# censusgeocode error
# 36047044900
# 13121000500
# censusgeocode error
# censusgeocode error
# 06037700501
# 48113020400
# censusgeocode error
# censusgeocode error
# 13121000500
# censusgeocode error
# 17031061100
# 09003500100
# 48113020400
# 06073002201
# censusgeocode error
# censusgeocode error
# 06083000900
# 06037208502
# censusgeocode error
# censusgeocode error
# 53033010300
# 08031001701
# 04013218300
# censusgeocode error
# 13121011900
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 48201310100
# censusgeocode error
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 16027021100
# 26163531900
# 26163520800
# 47157003400
# 06037576001
# 48453001100
# 48029190200
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 25025000803
# 16001000100
# censusgeocode error
# 16019970501
# censusgeocode error
# 30111000402
# 46103010200
# 38017000700
# 27053106200
# censusgeocode error
# 06075020100
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 11001010200
# censusgeocode error
# 48113020400
# 53033004900
# 06037212900
# 55079007700
# 55079014900
# 06059074106
# 06073005300
# 13121003500
# 06075022702
# censusgeocode error
# 06087101000
# 48201310900
# 48453001100
# censusgeocode error
# 32031002104
# 06073005300
# 35001002100
# 04013421202
# censusgeocode error
# censusgeocode error
# 12095018900
# 50
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.786
# Model:                            OLS   Adj. R-squared (uncentered):              0.772
# Method:                 Least Squares   F-statistic:                              57.47
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    9.32e-16
# Time:                        18:37:20   Log-Likelihood:                         -50.004
# No. Observations:                  50   AIC:                                      106.0
# Df Residuals:                      47   BIC:                                      111.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0172      0.507      0.034      0.973      -1.003       1.037
# x2             0.0272      0.007      4.128      0.000       0.014       0.040
# x3          5.296e-06    3.2e-06      1.657      0.104   -1.13e-06    1.17e-05
# ==============================================================================
# Omnibus:                       30.580   Durbin-Watson:                   1.252
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.508
# Skew:                           1.886   Prob(JB):                     1.20e-13
# Kurtosis:                       6.786   Cond. No.                     3.39e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.39e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tract_stats(names = ['pat app', 'supakaine', 'Kweku Collins', 'IshDARR'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 56
# 28
# related_artists search 1
# related_artists ra_help 3
# 110
# 78
# related_artists search 1
# related_artists ra_help 3
# 65
# 18
# related_artists search 1
# related_artists ra_help 3
# 67
# 23
# 36061003700
# 06037700501
# 06073005300
# 06073005300
# censusgeocode error
# 04013421202
# 48113020400
# 48453001100
# 12095018900
# 06001983200
# 06037212900
# censusgeocode error
# 16001000100
# 53063003500
# 16019970501
# 30063000202
# some other error
# 30111000402
# censusgeocode error
# 38017000700
# censusgeocode error
# 39035141100
# censusgeocode error
# 48201310100
# 13121003500
# censusgeocode error
# 36047030500
# 47157003400
# 48201310100
# censusgeocode error
# 48453001100
# 13121000500
# 37119004900
# censusgeocode error
# 09003500100
# 48113020400
# 06075017802
# 41051002203
# 36047044900
# 17031062800
# 13121000500
# 06037206031
# 06001402800
# 06073002201
# 04019000400
# 04005001200
# some other error
# 06083000900
# 06037208502
# 32003006700
# 11001010200
# censusgeocode error
# censusgeocode error
# 53033004900
# 06067001300
# 06037576001
# censusgeocode error
# 48029190200
# 48201210400
# 27053104400
# 36047044900
# 25025000803
# 06075020100
# 48201310100
# 06075012902
# censusgeocode error
# 53033008600
# 17031330100
# censusgeocode error
# 12095018900
# 12086002800
# 55079007700
# 55079014900
# 06059074106
# 13121003500
# 37183050900
# 17031221500
# 36061016001
# 37183052602
# 06037207710
# 06001402800
# 53033005301
# 08031002403
# 27053104400
# 09009361402
# 36047051900
# 06067001400
# 06037195803
# 06059074106
# 51760030200
# censusgeocode error
# 36061008300
# 04013421202
# 36061003100
# 37119000700
# censusgeocode error
# 64
# 5
# [3.2189861603351706, 3.1955627041686685, 1.5447516259418463]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.694
# Model:                            OLS   Adj. R-squared (uncentered):              0.679
# Method:                 Least Squares   F-statistic:                              46.11
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    1.10e-15
# Time:                        23:56:32   Log-Likelihood:                         -89.544
# No. Observations:                  64   AIC:                                      185.1
# Df Residuals:                      61   BIC:                                      191.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1205      0.076     -1.594      0.116      -0.272       0.031
# x2             0.0010      0.000      5.664      0.000       0.001       0.001
# x3         -1.624e-11   1.34e-11     -1.213      0.230    -4.3e-11    1.05e-11
# ==============================================================================
# Omnibus:                       15.165   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.042
# Skew:                           0.874   Prob(JB):                     1.64e-05
# Kurtosis:                       5.283   Cond. No.                     7.02e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.02e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['pat app', 'supakaine', 'Kweku Collins', 'IshDARR'], followers = 50000)

# plot_all_tours(tours)
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 56
# 28
# related_artists search 1
# related_artists ra_help 3
# 110
# 78
# related_artists search 1
# related_artists ra_help 3
# 65
# 18
# related_artists search 1
# related_artists ra_help 3
# 67
# 23
# [('KING A-K', '3hcl12H9yPcn5dhBqyNRfi', 1, 5729), ('Lildaddex', '7oD7RpIiQ76qugFcxYbAn6', 1, 7965), ('Lil Satan', '27Xh7VTUnXXdQi5KrBG2H3', 1, 7069), ('TKO', '30yNK6ul4uCxHnK36GD1fg', 1, 21386), ('Mitchos Da Menace', '4N9eOW77jpcMTy4qt2smkg', 1, 8766), ('DC The Don', '3YYbAExunnHv5pW7GUZefk', 1, 33430), ('Huskii', '7uXoqYYwYwTUMF2zSF9Fwl', 1, 14133), ('Exl', '6j5lxsz5UsEHXTgkwVC4ie', 1, 1925), ('Skrub', '4gBIvL912yEFl53RwEfLLV', 1, 3222), ('Surf', '6s2jNlpt8hb1wZ8ST4Wdxj', 1, 3819), ('Larry June', '1grN0519h2zYqpRtYbDZAl', 3, 30935), ('LNDN DRGS', '65d2Cw70rLuVwEZwQpHtFW', 3, 9808), ('Dusty McFly', '0ekbxDROhz27q5QvYDCOsj', 2, 1817), ('Vdon', '2uzaOMszD2lvSWPKjaYaTq', 2, 5156), ('Blade Icewood', '3WuFQUQAOAsFgnVlLKALM4', 2, 2553), ('Street Lord Juan', '5MUg1llyqJS5NwnFURpWKI', 2, 884), ('ALLBLACK', '1cutd8e41XvxXnFPOFIxMD', 2, 21145), ('Young Roddy', '7lVTwgQZCYQt20tvcPl6D4', 2, 28822), ('Doughboyz Cashout', '7fKiDS9ftTP9DsC9qTUhd6', 2, 25085), ('G Perico', '4Q2hTDZYFCohf17D5GvkIb', 2, 38651), ('Elujay', '1CgbNAF3Stnz1Tpipu3xdO', 4, 30981), ('ShaqIsDope', '3Is1kGaN2jmS0hB1Hn6dp4', 4, 22646), ('IshDARR', '1MlV4b7HGi4AiZWXholyVu', 4, 46054), ('Sean Leon', '5dtbsNKCK6Q9yZzdhZpaqW', 3, 19720), ('Childish Major', '4bMNzAopkqYTwkBLwMKsF1', 3, 43602), ('Myke Bogan', '5BLrsIX3Uipmt9QAiZGYEl', 2, 14004), ('Khary', '4489Zgs4RNq2ZtSh3UnOxZ', 2, 28108), ('Lute', '75WcpJKWXBV3o3cfluWapK', 2, 41709), ('Michael Christmas', '1POk07q5vJ4NcdOgkLyPzp', 2, 38633), ('Dave B.', '5bfqwcEcRrMhtY9smw3IeJ', 2, 44719), ('ShaqIsDope', '3Is1kGaN2jmS0hB1Hn6dp4', 5, 22646), ('IshDARR', '1MlV4b7HGi4AiZWXholyVu', 4, 46054), ('Sean Leon', '5dtbsNKCK6Q9yZzdhZpaqW', 4, 19720), ('Demrick', '3hEgzEeaZ0hb3UXx1U1JRR', 4, 21640), ('Elujay', '1CgbNAF3Stnz1Tpipu3xdO', 4, 30981), ('Childish Major', '4bMNzAopkqYTwkBLwMKsF1', 3, 43602), ('Anfa Rose', '6QyD04sHvKf1AjxkXrNRk1', 3, 31063), ('Quentin Miller', '6po19E0R9xffrgzrg84TC9', 3, 24159), ('Khary', '4489Zgs4RNq2ZtSh3UnOxZ', 2, 28108), ('Dave B.', '5bfqwcEcRrMhtY9smw3IeJ', 2, 44719)]
# 33

# %%
# optimal_path(tours)
# Out:
# ((39.9589828, -75.1502637), (38.9223987, -77.0422671), (42.33781, -83.05173), (41.939657, -87.663651), (33.76423, -84.35023), (29.75393, -95.36406), (30.26749, -97.73605), (32.78533, -96.80809), (39.74058, -104.97699)) 50.08033415149592
# [(39.9589828, -75.1502637), (38.9223987, -77.0422671), (42.33781, -83.05173), (41.939657, -87.663651), (33.76423, -84.35023), (29.75393, -95.36406), (30.26749, -97.73605), (32.78533, -96.80809), (39.74058, -104.97699)]
# (29.42472, -98.49149)
# (41.50832, -81.5803)
# (38.99748, -77.02793)
# (38.3009, -77.4591)
# (41.50337, -81.65417)
# (42.6367415, -83.2917046)
# (29.93356, -90.07001)
# (36.1528598, -86.7804525)
# (39.31884, -76.6195)
# [(39.9589828, -75.1502637), (39.31884, -76.6195), (38.99748, -77.02793), (38.9223987, -77.0422671), (38.3009, -77.4591), (41.50337, -81.65417), (41.50832, -81.5803), (42.33781, -83.05173), (42.6367415, -83.2917046), (41.939657, -87.663651), (36.1528598, -86.7804525), (33.76423, -84.35023), (29.93356, -90.07001), (29.75393, -95.36406), (30.26749, -97.73605), (32.78533, -96.80809), (29.42472, -98.49149), (39.74058, -104.97699)]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### West (https://djbooth.net/features/2017-08-22-west-coast-rappers-california-torch)

# %%
tract_stats(names = ['Dumbfoundead', 'Duckwrth', 'Trizz', 'Ill Camille', 'Chuuwee'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 79
# 41
# related_artists search 1
# related_artists ra_help 3
# 40
# 17
# related_artists search 1
# related_artists ra_help 3
# 69
# 42
# related_artists search 1
# related_artists ra_help 3
# 93
# 55
# related_artists search 1
# related_artists ra_help 3
# 76
# 42
# 25017353101
# 17031062800
# censusgeocode error
# 29095015800
# 08031003701
# 49035101900
# censusgeocode error
# 53033007500
# 06037207710
# 06073005300
# 06001402800
# 53033005301
# 08031002403
# censusgeocode error
# 17031221500
# 09009361402
# 06067001200
# 06023011500
# 04013114100
# censusgeocode error
# censusgeocode error
# 19103002100
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 17031330100
# 48453000902
# 36047055700
# 11001003800
# 36047003300
# 36061019800
# censusgeocode error
# 06075017802
# censusgeocode error
# 36047044900
# censusgeocode error
# censusgeocode error
# 06037700501
# 06075020100
# 48113020400
# 48201310100
# censusgeocode error
# 42101037600
# 51660000302
# 06073002201
# 04019000400
# 04005001200
# 06083000900
# censusgeocode error
# censusgeocode error
# 06037190201
# 06037121210
# 06059074106
# 06073006500
# 32003002604
# 06087101000
# 06075012000
# 06111002400
# 36061003100
# censusgeocode error
# 12095018900
# censusgeocode error
# 08031003500
# 17031070300
# 39035108701
# 26163522500
# 42101014200
# 11001010200
# censusgeocode error
# 39035141100
# 13121003000
# 48201310100
# 13121003500
# censusgeocode error
# 36047030500
# 48453001100
# censusgeocode error
# censusgeocode error
# 36061003001
# 24510040100
# censusgeocode error
# 11001004400
# 42101015800
# censusgeocode error
# censusgeocode error
# 36047011900
# censusgeocode error
# 25025000703
# 25025010701
# 33015069300
# 25017352700
# 41039003900
# 33015065008
# 06073005300
# 06059074106
# censusgeocode error
# 36047054900
# censusgeocode error
# 36081055300
# 36061003602
# 19103002100
# censusgeocode error
# censusgeocode error
# 08031001600
# censusgeocode error
# 47037019500
# 17031220902
# censusgeocode error
# 26081002000
# 26065004100
# 26081002600
# 25017353101
# 20045000200
# 36061005700
# 42101001600
# 39035107701
# censusgeocode error
# 04013113100
# 48453001100
# 06071001002
# 06037191301
# censusgeocode error
# 06059011300
# 36047051900
# 13121000500
# 06067001400
# censusgeocode error
# 06067001101
# 36047055500
# 36061009900
# censusgeocode error
# censusgeocode error
# 06067001300
# 13121003500
# 48453001100
# 06037600703
# 32003002604
# 06037700501
# 06073008305
# 06001402900
# censusgeocode error
# 20173009511
# 36061008300
# censusgeocode error
# 36061004200
# 12057002900
# 29189214602
# 48453000401
# 48029110100
# 48113015304
# 48453001911
# 36061003002
# 06037190100
# 36047055500
# 06037576001
# 48453001100
# 48029190200
# 48201210400
# 27053104400
# 25025000803
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 17031410900
# 27123034201
# 26163522400
# 26081002000
# censusgeocode error
# 113
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.764
# Model:                            OLS   Adj. R-squared (uncentered):              0.757
# Method:                 Least Squares   F-statistic:                              118.6
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    2.50e-34
# Time:                        12:30:51   Log-Likelihood:                         -122.76
# No. Observations:                 113   AIC:                                      251.5
# Df Residuals:                     110   BIC:                                      259.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2077      0.399     -0.521      0.604      -0.998       0.583
# x2             0.0325      0.005      6.890      0.000       0.023       0.042
# x3          3.488e-06   1.94e-06      1.797      0.075   -3.58e-07    7.33e-06
# ==============================================================================
# Omnibus:                       71.619   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.964
# Skew:                           2.330   Prob(JB):                     9.76e-62
# Kurtosis:                       9.161   Cond. No.                     4.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tract_stats(names = ['Dumbfoundead', 'Duckwrth', 'Trizz', 'Ill Camille', 'Chuuwee'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 79
# 41
# related_artists search 1
# related_artists ra_help 3
# 40
# 17
# related_artists search 1
# related_artists ra_help 3
# 69
# 42
# related_artists search 1
# related_artists ra_help 3
# 94
# 55
# related_artists search 1
# related_artists ra_help 3
# 76
# 42
# 17031220902
# some other error
# 26065006600
# 26081002000
# 26065004100
# 26081002600
# 25017353101
# 20045000200
# censusgeocode error
# 17031330100
# 08031003500
# 17031070300
# 39035108701
# 26163522500
# censusgeocode error
# 36047044900
# 11001010200
# 36061010100
# 25025000703
# 25025010701
# 33015069300
# censusgeocode error
# 41039003900
# 25017353101
# 33015065008
# 48453001100
# 06037600703
# censusgeocode error
# 06037700501
# 06073008305
# 06001402900
# 06083000900
# 48453001100
# censusgeocode error
# 06037700501
# 13121003000
# censusgeocode error
# 13121003500
# 06037199000
# 36047030500
# 36061005700
# 24510040100
# 42101001600
# 39035107701
# 17031061100
# 27053104400
# 04013113100
# 48453001100
# 06037190201
# 06037121210
# 06059074106
# 06073006500
# 32003002604
# 06087101000
# 06075012000
# 06111002400
# 47157003400
# 48201310100
# censusgeocode error
# censusgeocode error
# 41051002203
# censusgeocode error
# 13121000500
# censusgeocode error
# 06001402800
# 48201100000
# censusgeocode error
# censusgeocode error
# 36061006800
# 42101014200
# 53033007500
# 20173009511
# censusgeocode error
# 48453001100
# 48029190200
# 48201210400
# censusgeocode error
# 36047044900
# 25025000803
# 06073002201
# censusgeocode error
# 04005001200
# some other error
# 06037208502
# 32003006700
# 53033004900
# censusgeocode error
# censusgeocode error
# 41051005000
# 41059950600
# 32031000201
# 06075020100
# 32003000700
# 48453001100
# 36061003001
# 36061003100
# 06019000600
# 06037219901
# 22071007700
# 17031410900
# 27123034201
# 26163522400
# 26081002000
# 39049001820
# 06067001200
# censusgeocode error
# 04013114100
# 29510127500
# 29095016800
# 19103002100
# 31055000500
# 46099000100
# 06001401300
# 55079007700
# 55079014900
# 06073005300
# 06067001300
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 36061004200
# 12057002900
# 06037207710
# censusgeocode error
# 06001402800
# censusgeocode error
# censusgeocode error
# 17031221500
# 09009361402
# 36047051900
# 13121000500
# 06067001400
# censusgeocode error
# 06059074106
# 06019000300
# censusgeocode error
# 12086002800
# 12095015202
# 17031241400
# 48113020400
# 12095010300
# 06037197500
# 06065030501
# censusgeocode error
# censusgeocode error
# 39049003200
# 29095015800
# censusgeocode error
# 49035101900
# censusgeocode error
# 53033007500
# censusgeocode error
# 36061019800
# 06037207103
# censusgeocode error
# 36047023300
# 48453000902
# 36047055700
# 11001003800
# 111
# 5
# [3.7398248658872593, 3.40515228976438, 1.647760830364095]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.684
# Model:                            OLS   Adj. R-squared (uncentered):              0.675
# Method:                 Least Squares   F-statistic:                              77.99
# Date:                Wed, 11 Dec 2019   Prob (F-statistic):                    6.47e-27
# Time:                        00:43:23   Log-Likelihood:                         -141.62
# No. Observations:                 111   AIC:                                      289.2
# Df Residuals:                     108   BIC:                                      297.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1551      0.059     -2.619      0.010      -0.273      -0.038
# x2             0.0007      0.000      5.140      0.000       0.000       0.001
# x3          2.235e-11   1.45e-11      1.545      0.125   -6.32e-12     5.1e-11
# ==============================================================================
# Omnibus:                       79.700   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              437.147
# Skew:                           2.501   Prob(JB):                     1.19e-95
# Kurtosis:                      11.337   Cond. No.                     5.26e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.26e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['Dumbfoundead', 'Duckwrth', 'Trizz', 'Ill Camille', 'Chuuwee'], followers = 50000)

# plot_all_tours(tours)
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 79
# 41
# related_artists search 1
# related_artists ra_help 3
# 40
# 17
# related_artists search 1
# related_artists ra_help 3
# 69
# 42
# related_artists search 1
# related_artists ra_help 3
# 94
# 55
# related_artists search 1
# related_artists ra_help 3
# 76
# 42
# [('Crucial Star', '4vdAgNz4vrUZVvS0CaVvGJ', 4, 34009), ('Ovan', '4FuRHFtCeoYaeeVDKyyvbS', 4, 18628), ('The Quiett', '2qI1pO64eYqGUiv1XTw4cy', 3, 39270), ('Rad Museum', '6UdKtISMXYKSR8jcgtFePo', 3, 37688), ('2xxx!', '4cMtnnGdRvh8KIi2RA7ZeU', 3, 17175), ('Nafla', '3Zn6C68VCosoQrxu4D2Btr', 2, 31301), ('DJ DOC', '3kDgt4vVKGTLmtC3FkOwWF', 2, 5132), ('Jvcki Wai', '4bjcB3ZKiHgPzJvY2S2FLN', 2, 22970), ('NELL', '5WY88tCMFA6J6vqSN3MmDZ', 2, 31045), ('Outsider', '1i4Y4WlFFetQV14Z8UDdvr', 2, 5273), ('Elujay', '1CgbNAF3Stnz1Tpipu3xdO', 4, 30981), ('Childish Major', '4bMNzAopkqYTwkBLwMKsF1', 3, 43602), ('Zelooperz', '5j93hwFBNo29RJMsWvtzj8', 2, 9906), ('Dave B.', '5bfqwcEcRrMhtY9smw3IeJ', 2, 44719), ('100 gecs', '6PfSUFtkMVoDkx4MQkzOi3', 2, 25356), ('Innanet James', '7p1KdHKrIDsXbiHnRNPOTG', 1, 17133), ('Khary', '4489Zgs4RNq2ZtSh3UnOxZ', 1, 28108), ('Trapo', '1ajTetyk95Ba8KUEYn7PT4', 1, 19462), ('Anonymuz', '625BWS4LmjJe3a82OCSFsm', 1, 25425), ('Topaz Jones', '76bAuLD5jMIT1YDJ84KB8l', 1, 33033), ('ShaqIsDope', '3Is1kGaN2jmS0hB1Hn6dp4', 5, 22646), ('Derin Falana', '5yjfk1YZOcpDKqLEgvE9WG', 5, 10096), ('Sean Leon', '5dtbsNKCK6Q9yZzdhZpaqW', 4, 19720), ('Demrick', '3hEgzEeaZ0hb3UXx1U1JRR', 4, 21640), ('Quentin Miller', '6po19E0R9xffrgzrg84TC9', 4, 24159), ('DillanPonders', '1TlmLsx42aT281z8NWrKef', 3, 6107), ('Kyle Bent', '2c8n0uEGtZxolOWtE1dySR', 3, 12392), ('IshDARR', '1MlV4b7HGi4AiZWXholyVu', 3, 46054), ('Sahtyre', '1ZHmdzn0KzjEICyi9v6oDU', 2, 4176), ('CJay', '5nJCXAh5NRTz0yAZWMJGYM', 2, 8615), ('Skyzoo', '0qHfqHyHZnxvv1lfkJraQc', 7, 38040), ('Illa J', '72zigmOdJbIsz0iIRhCBvp', 6, 47631), ('Tall Black Guy', '2bz6GlqjAN5fTFWvy0rmSP', 6, 25911), ('Slakah The Beatchild', '3ecInXeVEuySk8y1AYFA74', 5, 20793), ('Georgia Anne Muldrow', '2RdnkH5txHb9c4vGwq0I31', 5, 31015), ('Fatima', '5uNCGgWH5Id1cW8kh9Sc67', 5, 28127), ('Eric Lau', '68P6JiHWJsv5VqfLPchS1n', 5, 21682), ('Damu The Fudgemunk', '7Mws36yO3takBR2WMsXOkM', 5, 35105), ('Taylor McFerrin', '0yLmsf6RBPYqm6hvFJCPg6', 5, 43152), ('Terrace Martin', '7MNEVabc4cs19CbzAFZmXz', 4, 42285), ('Willie The Kid', '0hZvVmOluFCV1ZjvvqtRB6', 4, 14259), ('IshDARR', '1MlV4b7HGi4AiZWXholyVu', 4, 46054), ('Trademark Da Skydiver', '2RPgvowoS8BYurtbUjwKjt', 3, 36987), ('ShaqIsDope', '3Is1kGaN2jmS0hB1Hn6dp4', 3, 22646), ('Warm Brew', '51YACffgZvQwjs8J4ZVDQF', 3, 22387), ('Roc Marciano', '5X0V59ipZnbvnubW0rQVri', 3, 46411), ('Skeme', '6TlLdicGl92pqnySP64n2g', 3, 34984), ('Nickelus F', '68DGxDpMWfSsPJEjT4wQnW', 2, 13122), ('Elujay', '1CgbNAF3Stnz1Tpipu3xdO', 2, 30981), ('Wiki', '78X7quh8fqAGZ42OpLmUW0', 2, 20648)]
# 47

# %%
# optimal_path(tours)

# %% [markdown]
# ### East Coast (https://www.complex.com/music/2018/05/underground-rappers-you-should-know/dark-lo)

# %%
tract_stats(names = ['Mach-Hommy', 'Tha God Fahim', 'Crimeapple', 'Al Divino', 'Dark Lo'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 107
# 54
# related_artists search 1
# related_artists ra_help 3
# 130
# 38
# related_artists search 1
# related_artists ra_help 3
# 127
# 41
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 127
# 40
# censusgeocode error
# 36055003300
# 25017353101
# 23005000100
# censusgeocode error
# 50015953600
# 04013106600
# 06037700501
# 06037207710
# censusgeocode error
# 06001402800
# 53033005301
# 08031002403
# 27053104400
# censusgeocode error
# 09009361402
# 13089020900
# 06059075002
# 06019000300
# 06019000600
# 06019004408
# 12086002800
# 06037219901
# 22071007700
# censusgeocode error
# 27123034201
# 26163522400
# censusgeocode error
# 39049001820
# 36061012500
# 17031061100
# 27053106200
# censusgeocode error
# 06037212900
# 42101037600
# 11001004801
# censusgeocode error
# 42101014400
# censusgeocode error
# censusgeocode error
# 06075020100
# censusgeocode error
# censusgeocode error
# 48113020400
# censusgeocode error
# 48201310100
# 13121000500
# 37119004900
# 09003500100
# 48113020400
# censusgeocode error
# 34021002100
# 25017353101
# 39153505700
# 06071001002
# 36061007900
# 08031003001
# 25027731202
# 36061003001
# 24510040100
# censusgeocode error
# 11001004400
# censusgeocode error
# 36047044900
# 51760040200
# censusgeocode error
# censusgeocode error
# 24033807200
# 51760030200
# 37183050100
# 37119001300
# 36061008300
# 32003006800
# 06037195803
# 27053104400
# 47037016500
# censusgeocode error
# 26065006600
# 26081002000
# 26065004100
# 26081002600
# 20045000200
# 36061005700
# 42101001600
# censusgeocode error
# censusgeocode error
# 62
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.803
# Model:                            OLS   Adj. R-squared (uncentered):              0.793
# Method:                 Least Squares   F-statistic:                              80.27
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    8.33e-21
# Time:                        12:38:23   Log-Likelihood:                         -62.385
# No. Observations:                  62   AIC:                                      130.8
# Df Residuals:                      59   BIC:                                      137.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.2158      0.453     -0.477      0.635      -1.121       0.690
# x2             0.0416      0.004     10.893      0.000       0.034       0.049
# x3         -3.171e-10   1.02e-09     -0.311      0.757   -2.36e-09    1.72e-09
# ==============================================================================
# Omnibus:                       14.524   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.063
# Skew:                           1.185   Prob(JB):                     0.000325
# Kurtosis:                       3.777   Cond. No.                     4.45e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.45e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tract_stats(names = ['Mach-Hommy', 'Tha God Fahim', 'Crimeapple', 'Al Divino', 'Dark Lo'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 107
# 54
# related_artists search 1
# related_artists ra_help 3
# 130
# 38
# related_artists search 1
# related_artists ra_help 3
# 127
# 41
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 127
# 40
# 06001983200
# 06037212900
# 42101037600
# 26163520700
# censusgeocode error
# 06037207301
# 08059009845
# 01073002400
# 37063000200
# 19061000900
# censusgeocode error
# 06037700501
# 13089020900
# 06059075002
# censusgeocode error
# 36061012500
# 17031061100
# 27053106200
# censusgeocode error
# 06071001002
# censusgeocode error
# 36061007900
# 08031003001
# 36061005700
# 24510040100
# 42101001600
# 39035107701
# 27053104400
# censusgeocode error
# 48453001100
# 13121003000
# censusgeocode error
# 37135011700
# 37119001400
# 51760020500
# 24033807200
# 48113020400
# 48201310100
# 13121000500
# 37119004900
# 09003500100
# 36047044700
# censusgeocode error
# 42101014400
# 36061004200
# 06037408800
# censusgeocode error
# censusgeocode error
# 06001405700
# 36081053500
# some other error
# 17031241500
# 17031241400
# 36047048500
# 17031241400
# 17031070200
# 17031310600
# censusgeocode error
# 32003006800
# 06037195803
# 27053104400
# 06019000600
# 06037219901
# 22071007700
# 17031410900
# censusgeocode error
# censusgeocode error
# 26081002000
# censusgeocode error
# 25017351100
# censusgeocode error
# 25025000704
# 25017353101
# 25025000703
# 36055003300
# 23005000100
# 34037374600
# 50015953600
# 04013106600
# 47037016500
# censusgeocode error
# 42101037600
# censusgeocode error
# 44007000800
# 34013016800
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 53033005301
# 17031221500
# 09009361402
# 06019000300
# 06019004408
# censusgeocode error
# 68
# 5
# [4.6084710761150305, 3.700688728516091, 2.5545136938413715]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.725
# Model:                            OLS   Adj. R-squared (uncentered):              0.712
# Method:                 Least Squares   F-statistic:                              57.00
# Date:                Wed, 11 Dec 2019   Prob (F-statistic):                    3.52e-18
# Time:                        00:52:56   Log-Likelihood:                         -81.527
# No. Observations:                  68   AIC:                                      169.1
# Df Residuals:                      65   BIC:                                      175.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1816      0.078     -2.336      0.023      -0.337      -0.026
# x2             0.0007      0.000      4.554      0.000       0.000       0.001
# x3         -3.486e-12   1.96e-11     -0.178      0.859   -4.26e-11    3.57e-11
# ==============================================================================
# Omnibus:                        3.778   Durbin-Watson:                   1.350
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                2.903
# Skew:                           0.409   Prob(JB):                        0.234
# Kurtosis:                       3.598   Cond. No.                     6.34e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.34e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['Mach-Hommy', 'Tha God Fahim', 'Crimeapple', 'Al Divino', 'Dark Lo'], followers = 50000)

# plot_all_tours(tours)
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 107
# 54
# related_artists search 1
# related_artists ra_help 3
# 130
# 38
# related_artists search 1
# related_artists ra_help 3
# 127
# 41
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 127
# 40
# [('DJ Muggs', '7pDkjftAxiFHomWsPNkapS', 4, 29831), ('Skyzoo', '0qHfqHyHZnxvv1lfkJraQc', 4, 38040), ('Planet Asia', '7dGfoIWAb0h9eGpl3vEkVo', 4, 28608), ("Mr. Muthafuckin' eXquire", '1Sq6VkcHqHAuFvURbH3sXQ', 3, 12186), ('Armand Hammer', '3SCI7sXHUZIeDKMWC5NT9C', 3, 9917), ('Havoc', '6UnvX7Zx85VNjOpLdaq49W', 3, 46181), ('Roc Marciano', '5X0V59ipZnbvnubW0rQVri', 3, 46411), ('Ras Kass', '0OiS4KHxViIFnJooFTXl7V', 3, 38770), ('Zelooperz', '5j93hwFBNo29RJMsWvtzj8', 3, 9906), ('Westside Gunn', '0ABk515kENDyATUdpCKVfW', 3, 48445), ('Westside Gunn', '0ABk515kENDyATUdpCKVfW', 4, 48445), ('Skyzoo', '0qHfqHyHZnxvv1lfkJraQc', 4, 38040), ('Benny The Butcher', '5Matrg5du62bXwer29cU5T', 4, 36362), ("Mr. Muthafuckin' eXquire", '1Sq6VkcHqHAuFvURbH3sXQ', 3, 12186), ('Conway the Machine', '67gqUXxHedeUGDTxwBzdjS', 3, 38747), ('Roc Marciano', '5X0V59ipZnbvnubW0rQVri', 3, 46411), ('Medhane', '6lTiYE2IL4FUqf0CgGjI5i', 2, 4877), ('Chris Crack', '3wws8s15DuuQWiG2xct414', 2, 4074), ('Zelooperz', '5j93hwFBNo29RJMsWvtzj8', 2, 9906), ('Wiki', '78X7quh8fqAGZ42OpLmUW0', 2, 20648), ('Westside Gunn', '0ABk515kENDyATUdpCKVfW', 4, 48445), ('Skyzoo', '0qHfqHyHZnxvv1lfkJraQc', 4, 38040), ('Benny The Butcher', '5Matrg5du62bXwer29cU5T', 4, 36362), ("Mr. Muthafuckin' eXquire", '1Sq6VkcHqHAuFvURbH3sXQ', 3, 12186), ('Conway the Machine', '67gqUXxHedeUGDTxwBzdjS', 3, 38747), ('Roc Marciano', '5X0V59ipZnbvnubW0rQVri', 3, 46411), ('Meyhem Lauren', '4lph4e07jjlKkioG1bQx95', 2, 25948), ('Termanology', '7oF48iRjggIDjtfRcmmMvl', 2, 23662), ('Chris Crack', '3wws8s15DuuQWiG2xct414', 2, 4074), ('Zelooperz', '5j93hwFBNo29RJMsWvtzj8', 2, 9906), ('Westside Gunn', '0ABk515kENDyATUdpCKVfW', 4, 48445), ('Skyzoo', '0qHfqHyHZnxvv1lfkJraQc', 4, 38040), ('Benny The Butcher', '5Matrg5du62bXwer29cU5T', 4, 36362), ('Conway the Machine', '67gqUXxHedeUGDTxwBzdjS', 3, 38747), ('Roc Marciano', '5X0V59ipZnbvnubW0rQVri', 3, 46411), ('Termanology', '7oF48iRjggIDjtfRcmmMvl', 3, 23662), ('Meyhem Lauren', '4lph4e07jjlKkioG1bQx95', 2, 25948), ('Nems', '1jSMH3JqXunssXcsZSKTJ4', 2, 3570), ('Chris Crack', '3wws8s15DuuQWiG2xct414', 2, 4074), ('LNDN DRGS', '65d2Cw70rLuVwEZwQpHtFW', 2, 9808)]
# 19

# %%
# optimal_path(tours)

# %% [markdown]
# ### South (https://www.complex.com/music/2018/05/underground-rappers-you-should-know/dark-lo)

# %%
tract_stats(names = ['D Flowers', 'AJ McQueen', 'Lajan Slim', 'Stunna 4 Vegas', 'Deniro Farrar'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 121
# 75
# related_artists search 1
# related_artists ra_help 3
# 105
# 75
# related_artists search 1
# related_artists ra_help 3
# 42
# 33
# related_artists search 1
# related_artists ra_help 3
# 66
# 47
# 36081055900
# 42101038300
# 25017353101
# 25017353101
# 53033006600
# 13121010304
# 12057003600
# 12095018900
# 12099007759
# censusgeocode error
# 13121006500
# 12086000501
# 48201230200
# 48113020400
# censusgeocode error
# 12086002004
# 06037207302
# 51019030103
# 06073019303
# censusgeocode error
# 12086002300
# 06037212900
# 06037700501
# 48201310100
# 06037195803
# 11001004801
# 08001009308
# 32003001200
# 04013421400
# censusgeocode error
# 35001002100
# 06037206050
# 04013421400
# 13121003100
# 13121006500
# censusgeocode error
# censusgeocode error
# 13245010104
# 36047022100
# 12057010213
# 39017014000
# censusgeocode error
# 39165031904
# censusgeocode error
# 39017010909
# 39061023100
# 13121009700
# 12031002502
# censusgeocode error
# 06075020700
# 06073005200
# 04013061020
# 32003003411
# 51540000401
# 32031002104
# 06037212900
# 06037208000
# 25027731500
# 06037226001
# 53033022500
# 48113001900
# 48201211400
# censusgeocode error
# 22071013400
# 28049000200
# 01097000200
# censusgeocode error
# 13121009700
# 12011031001
# censusgeocode error
# 48201210100
# 32003006700
# censusgeocode error
# 16001000100
# censusgeocode error
# 04013421202
# 04019000100
# 06037207301
# 11001003800
# censusgeocode error
# censusgeocode error
# 17031081600
# 06075015900
# censusgeocode error
# 12086004500
# 06059086303
# 48085030504
# 12086004000
# 08041002101
# censusgeocode error
# 12095018900
# 47065003100
# 48453001100
# 17031330100
# 17031150200
# 36081047900
# 36059412100
# 36047048500
# 36081098100
# 51660000402
# censusgeocode error
# 06067001400
# 06075020100
# 41051010600
# 08031001701
# 55079007700
# 55079014900
# censusgeocode error
# 06073005300
# 06075017802
# 06067001300
# 13121003500
# 41039003900
# 32003002302
# 55079007800
# 30111000402
# 37119005838
# 12095017017
# 25025090200
# 25017339100
# 42133021720
# 39035107802
# 42049011202
# 39049009740
# 98
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.735
# Method:                 Least Squares   F-statistic:                              91.37
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    6.80e-28
# Time:                        13:01:18   Log-Likelihood:                         -107.75
# No. Observations:                  98   AIC:                                      221.5
# Df Residuals:                      95   BIC:                                      229.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4509      0.337      1.340      0.183      -0.217       1.119
# x2             0.0211      0.005      4.661      0.000       0.012       0.030
# x3          5.671e-06   2.15e-06      2.640      0.010    1.41e-06    9.93e-06
# ==============================================================================
# Omnibus:                       98.767   Durbin-Watson:                   2.178
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1136.288
# Skew:                           3.316   Prob(JB):                    1.81e-247
# Kurtosis:                      18.307   Cond. No.                     3.17e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tract_stats(names = ['D Flowers', 'AJ McQueen', 'Lajan Slim', 'Stunna 4 Vegas', 'Deniro Farrar'], followers = 50000, demo = 'black')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 121
# 75
# related_artists search 1
# related_artists ra_help 3
# 105
# 75
# related_artists search 1
# related_artists ra_help 3
# 42
# 33
# related_artists search 1
# related_artists ra_help 3
# 66
# 47
# 42101038300
# 25017353101
# 25017353101
# 53033006600
# 53033022500
# some other error
# 48113001900
# 48201211400
# 08001009308
# some other error
# 32003001200
# 04013421400
# 04013422203
# censusgeocode error
# 06037206050
# 04013421400
# 51540000401
# 36081038302
# some other error
# 12086002300
# 06037212900
# 06037700501
# 48201310100
# 06037195803
# 11001004801
# 39035141100
# 13121003000
# 48201310100
# censusgeocode error
# 06037199000
# 36047030500
# 13245010104
# 36047022100
# 13121009700
# 12011031001
# 48453001100
# 17031330100
# 17031150200
# 06071004900
# 13121006500
# 12086000501
# 48201230200
# 48113020400
# 48201422800
# 12086002004
# 12086004500
# 06059086303
# 48085030504
# 12086004000
# 08041002101
# 12086004403
# 36081055900
# 06073002201
# 04019000400
# 04005001200
# some other error
# censusgeocode error
# censusgeocode error
# 32003006700
# 32031002104
# 06037212900
# 06037208000
# 25027731500
# censusgeocode error
# 12057010213
# 39017014000
# 04017960600
# censusgeocode error
# 39017010909
# censusgeocode error
# 39061023100
# 13121009700
# 06037207301
# 11001003800
# 36047051900
# censusgeocode error
# 17031081600
# 06075015900
# 48201100000
# censusgeocode error
# censusgeocode error
# 06073018513
# 04013814900
# 06037404201
# 06037189702
# 06085500800
# 48491020320
# 48113020400
# 26081002000
# 26163520700
# 11001011100
# censusgeocode error
# 06073021400
# censusgeocode error
# 06085512001
# 06013309000
# 06037224020
# 06073005300
# 12095018900
# 47065003100
# 51660000402
# 06059074106
# 06067001400
# 06075020100
# 41051010600
# 48201210100
# 08031001701
# 41039003900
# 32003002302
# 55079007800
# 30111000402
# 85
# 5
# [3.7854973895350854, 3.888464193524493, 1.5705926373580563]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.685
# Model:                            OLS   Adj. R-squared (uncentered):              0.674
# Method:                 Least Squares   F-statistic:                              59.53
# Date:                Wed, 11 Dec 2019   Prob (F-statistic):                    1.57e-20
# Time:                        01:03:37   Log-Likelihood:                         -100.43
# No. Observations:                  85   AIC:                                      206.9
# Df Residuals:                      82   BIC:                                      214.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1400      0.061     -2.291      0.025      -0.262      -0.018
# x2             0.0005      0.000      3.959      0.000       0.000       0.001
# x3          2.361e-11   1.28e-11      1.847      0.068   -1.83e-12     4.9e-11
# ==============================================================================
# Omnibus:                       87.465   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1110.304
# Skew:                           3.108   Prob(JB):                    7.95e-242
# Kurtosis:                      19.579   Cond. No.                     5.99e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.99e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['D Flowers', 'AJ McQueen', 'Lajan Slim', 'Stunna 4 Vegas', 'Deniro Farrar'], followers = 50000)

# plot_all_tours(tours)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ed1b5ec3e438> in <module>
# ----> 1 tours = compile_tours(names = ['D Flowers', 'AJ McQueen', 'Lajan Slim', 'Stunna 4 Vegas', 'Deniro Farrar'], followers = 50000)
#       2
#       3 # plot_all_tours(tours)
#
# NameError: name 'compile_tours' is not defined

# %%
# optimal_path(tours)

# %% [markdown]
# ## Rock

# %%
tours = compile_tours(names = ['The Bonfire Set', 'Elephant Rifle', 'LO MOON', 'PINKY PINKY', 'My Goodness'], followers = 50000)

optimal_path(tours)
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 128
# 72
# related_artists search 1
# related_artists ra_help 3
# 93
# 47
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 96
# 51
# [('Big Black', '5EYkvHZuGM3pwU3DZUrrZ3', 14, 41236), ('Wipers', '0sTTw3dw3EA0c7NaZnrJd2', 14, 28922), ('The Jesus Lizard', '6r26MaDr8bqNALjXgYPXMa', 14, 46910), ('Mission Of Burma', '5UMQV83wwZCCvRSQCVjZw6', 13, 37760), ('Unwound', '4YjpqCSDD7zwMQgPYJMqb0', 13, 28694), ('Shellac', '6I8R5MFTlez7rHCsH4cx0u', 12, 48145), ('Lightning Bolt', '2og3FOCLYXT9H7IYE6QPUq', 9, 44518), ('Brainiac', '0No2Og1pAwgw0eMmY6PPVP', 9, 8969), ('Flipper', '20VDXslLsXlLgSF765m1Ug', 9, 22700), ('Drive Like Jehu', '7FbdCzKUwoZs1v9bCl43Ev', 8, 26156), ('Talos', '5pdzKTGQAcRcxDOfN4mXSc', 7, 38886), ('VHS Collection', '2Nvaq4y2ygxIqfwXyz0HeH', 7, 43655), ('Mating Ritual', '4ZeB1hzT2mSZrf7wszOqHs', 6, 19305), ('Handsome Ghost', '3IaqL9bsZtYJkqNLiovVho', 5, 45179), ('courtship.', '2OK16hAFRHoJiFZKeZe8A8', 5, 30611), ('Arctic Lake', '0IEPb9ily3E5IAYMSkwtQ6', 5, 19008), ('Zola Blood', '3oxkIoEAyXXQlLTZXlffLJ', 5, 37360), ('Bay Ledges', '7FhRUp59cBzPaxobsRY1Nc', 4, 14955), ('Arctic Lake', '0IEPb9ily3E5IAYMSkwtQ6', 4, 19008), ('Fenne Lily', '7iPH2BRBF9wKa6ljxvdext', 3, 48030), ('The Parlor Mob', '1U4d20oJAq9aLa2mhDGwVV', 6, 33795), ('Goodbye June', '1l9I7G8J8AnMScWQwlNJ4M', 6, 49164), ('Middle Brother', '5au2vhHl8DViD9PUxUZBTb', 6, 35190), ('The Felice Brothers', '4Ajgo7nAsTzjSFymIfBjZ1', 6, 44772), ('Dead Man Winter', '3S3wKbKQc3QdCKExlBBzxw', 6, 14026), ('Futurebirds', '4Ait1vX2ZaWPrkua8Z664O', 5, 22676), ('Anders Osborne', '3WUUtA45g7X0jbeywZz888', 5, 30892), ('The Stone Foxes', '40N10exWtaCVUtBMftQn3t', 5, 43236), ('Cotton Jones', '6RHDASo3OVNiNY2nrGx3qc', 4, 41709), ('Patrick Sweany', '35mDUnsSVfkJpgjIXHsPC5', 4, 28307)]
# 29

# %% [markdown]
# ### West
#
# (https://www.pastemagazine.com/blogs/lists/2014/07/10-nevada-bands-you-should-listen-to-now.html)
# (https://buzzbands.la/2017/12/27/bands-watch-2018-20-artists-new-year/)
# (https://www.pastemagazine.com/blogs/lists/2012/05/1x-washington-bands-you-should-listen-to-now.html)

# %%
tract_stats(names = ['The Bonfire Set', 'Elephant Rifle', 'LO MOON', 'PINKY PINKY', 'My Goodness'], followers = 50000, demo='non-white')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 128
# 72
# related_artists search 1
# related_artists ra_help 3
# 93
# 46
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 96
# 51
# 47037016200
# 26163507500
# 18097355900
# 21009950200
# 25017339801
# censusgeocode error
# 36067003200
# 55073000100
# 42071000100
# censusgeocode error
# censusgeocode error
# 24510120600
# 42101037600
# censusgeocode error
# 53033006600
# 21111006500
# 39093060100
# censusgeocode error
# 42003411000
# 47031970500
# 47141000600
# 47035970602
# 06037265301
# 06037190201
# censusgeocode error
# censusgeocode error
# 25009217400
# 08031002403
# 08069000100
# 22071007800
# censusgeocode error
# 06073017200
# 06037190510
# 06037215101
# 06075016200
# 49035114000
# 08031001600
# 29095015800
# 38017000700
# 27137001900
# 27123032100
# 27103480600
# 27099000410
# censusgeocode error
# 24510120500
# 42101036900
# 39049000600
# censusgeocode error
# 27123034201
# 53033004700
# 41051002203
# 18105000100
# 44005040900
# censusgeocode error
# 06059063601
# 06075016400
# censusgeocode error
# 06037700501
# 48453000902
# 48029190200
# censusgeocode error
# 42101000401
# 36047056500
# 25017353101
# censusgeocode error
# 06041127000
# censusgeocode error
# 22071012102
# 06059042201
# 32031000101
# 06067008510
# censusgeocode error
# 08041006700
# 08031001600
# censusgeocode error
# 08085966300
# 41017001400
# 41051003401
# censusgeocode error
# censusgeocode error
# 41051005200
# 53033005301
# 13121003000
# 48453001100
# 26163517200
# 25025070200
# 11001004400
# 48453001100
# 48113020400
# 08031003701
# censusgeocode error
# 53033007500
# censusgeocode error
# censusgeocode error
# 06075015900
# 48453002316
# censusgeocode error
# 11001004400
# 25017353101
# 39035141100
# 17031061100
# 27053104400
# 08031001500
# 36029013800
# 19163010900
# 36109000700
# 06037209300
# 06073002201
# 06075016900
# 04013110702
# 48453001100
# 48201100000
# 47037019500
# censusgeocode error
# 17031031200
# 35001002100
# 06075016600
# 53053061700
# 53033009200
# 27053104400
# 08031002602
# 49035102500
# 16001000100
# 56039967701
# 06037700501
# 06059074106
# 06079011503
# 06087101000
# 06001422900
# 41051002100
# 53033010300
# 06037208502
# 101
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.811
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              139.9
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    2.72e-35
# Time:                        15:14:57   Log-Likelihood:                         -87.872
# No. Observations:                 101   AIC:                                      181.7
# Df Residuals:                      98   BIC:                                      189.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7195      0.280      2.565      0.012       0.163       1.276
# x2             0.0277      0.003     10.060      0.000       0.022       0.033
# x3         -1.012e-10   8.97e-10     -0.113      0.910   -1.88e-09    1.68e-09
# ==============================================================================
# Omnibus:                       65.209   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.617
# Skew:                           2.175   Prob(JB):                     5.27e-66
# Kurtosis:                      10.246   Cond. No.                     3.19e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.19e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['The Bonfire Set', 'Elephant Rifle', 'LO MOON', 'PINKY PINKY', 'My Goodness'], followers = 50000)

# plot_all_tours(tours)
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 128
# 72
# related_artists search 1
# related_artists ra_help 3
# 93
# 46
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 96
# 51
# [('Big Black', '5EYkvHZuGM3pwU3DZUrrZ3', 14, 41196), ('Wipers', '0sTTw3dw3EA0c7NaZnrJd2', 14, 28886), ('The Jesus Lizard', '6r26MaDr8bqNALjXgYPXMa', 14, 46874), ('Unwound', '4YjpqCSDD7zwMQgPYJMqb0', 13, 28694), ('Mission Of Burma', '5UMQV83wwZCCvRSQCVjZw6', 13, 37738), ('Shellac', '6I8R5MFTlez7rHCsH4cx0u', 12, 48090), ('Brainiac', '0No2Og1pAwgw0eMmY6PPVP', 9, 8955), ('Lightning Bolt', '2og3FOCLYXT9H7IYE6QPUq', 9, 44470), ('Flipper', '20VDXslLsXlLgSF765m1Ug', 9, 22679), ('Hot Snakes', '5hEP2P4E1FjoFYdhhxe7vi', 8, 28157), ('Talos', '5pdzKTGQAcRcxDOfN4mXSc', 7, 38802), ('VHS Collection', '2Nvaq4y2ygxIqfwXyz0HeH', 7, 43617), ('Mating Ritual', '4ZeB1hzT2mSZrf7wszOqHs', 6, 19291), ('Arctic Lake', '0IEPb9ily3E5IAYMSkwtQ6', 5, 19008), ('Handsome Ghost', '3IaqL9bsZtYJkqNLiovVho', 5, 45179), ('courtship.', '2OK16hAFRHoJiFZKeZe8A8', 5, 30574), ('Zola Blood', '3oxkIoEAyXXQlLTZXlffLJ', 5, 37360), ('Bay Ledges', '7FhRUp59cBzPaxobsRY1Nc', 4, 14923), ('Henry Green', '0VbDAlm2KUlKI5UhXRBKWp', 3, 31633), ('Future Generations', '3wKj5PmSpnrtz9n9hG2QCA', 3, 14310), ('The Parlor Mob', '1U4d20oJAq9aLa2mhDGwVV', 6, 33795), ('Middle Brother', '5au2vhHl8DViD9PUxUZBTb', 6, 35190), ('Dead Man Winter', '3S3wKbKQc3QdCKExlBBzxw', 6, 14019), ('Goodbye June', '1l9I7G8J8AnMScWQwlNJ4M', 6, 49164), ('The Felice Brothers', '4Ajgo7nAsTzjSFymIfBjZ1', 6, 44752), ('The Stone Foxes', '40N10exWtaCVUtBMftQn3t', 5, 43225), ('Futurebirds', '4Ait1vX2ZaWPrkua8Z664O', 5, 22649), ('Anders Osborne', '3WUUtA45g7X0jbeywZz888', 5, 30875), ('Patrick Sweany', '35mDUnsSVfkJpgjIXHsPC5', 4, 28289), ('Phil Cook', '3pqmhj6H08f5rGsnVroz9E', 4, 11191)]
# 30

# %%
# optimal_path(tours)

# %% [markdown]
# ### East
#
# (https://gooddeedseats.com/45-up-and-coming-rock-bands/)

# %%
tract_stats(names = ['Air Traffic Controller', 'Big Thief', 'J and The 9s', 'Charly Bliss', 'Hop Along'], followers = 50000, demo='non-white')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 61
# 40
# related_artists search 1
# related_artists ra_help 3
# 75
# 24
# related_artists search 1
# related_artists ra_help 3
# 42
# 23
# related_artists search 1
# related_artists ra_help 3
# 130
# 50
# related_artists search 1
# related_artists ra_help 3
# 126
# 78
# 42071000100
# 51660000402
# 37021000100
# 51760040800
# 34029723600
# 24035810800
# 42071000100
# 42071000100
# 06075010600
# 06083000900
# 06019002200
# 06079011101
# 06067001400
# 06087101000
# 06073005300
# 06037207400
# 06037183810
# 06037191710
# 27123032100
# 29095016700
# 08031001600
# 17031062800
# 05119004400
# 47037016200
# censusgeocode error
# 18097355900
# censusgeocode error
# censusgeocode error
# 48309000400
# censusgeocode error
# 17143002800
# 17031061100
# 13121000500
# 49035114000
# 49035114000
# 49011126001
# 49035114000
# 49049002400
# 49049002400
# censusgeocode error
# 06073002201
# 06037194402
# 06059088602
# censusgeocode error
# censusgeocode error
# 06075022702
# 17031070300
# 26081002000
# 50007000800
# 25017351100
# 09009165400
# 34017006500
# 47037019500
# censusgeocode error
# 37119001400
# 37135010705
# 51059460800
# 42101002400
# 36061003001
# 42101000401
# 11001002801
# 51760040200
# 39035161600
# 17031062500
# 06037207302
# 06037183810
# 09009165400
# 42003981000
# some other error
# 36109000700
# 39035161600
# 29510124300
# 17031221100
# 17077010800
# 05119001800
# censusgeocode error
# censusgeocode error
# 48201310900
# 22071009700
# 42071013501
# 42101036900
# 36111953800
# 36061003001
# 42041010300
# 42071000100
# 42071000100
# censusgeocode error
# 06037408800
# 06037226001
# 41051002100
# censusgeocode error
# 49035102500
# 37183050100
# censusgeocode error
# 33015069100
# 50007000800
# 42071000100
# 51710002800
# 25025010405
# censusgeocode error
# 50007003600
# censusgeocode error
# 36029016500
# 11001001402
# censusgeocode error
# 36047056500
# 42101036900
# 36047042700
# 06073017200
# 06037190510
# 06037215101
# 06075016200
# 49035114000
# 08031001600
# 29095015800
# 39009972800
# 17031809900
# 21037053200
# 50007000200
# 23005000600
# 09009140100
# 36111952400
# censusgeocode error
# 25017354200
# 25013811400
# censusgeocode error
# censusgeocode error
# 34025807003
# 11001003800
# 37135010705
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 36029016500
# censusgeocode error
# 34025807003
# censusgeocode error
# censusgeocode error
# 48453001100
# 48113020400
# 08031003701
# 48113001900
# 48453001100
# 05143011300
# 40143002500
# 39049003200
# censusgeocode error
# 36103201004
# 25025000703
# 11001008402
# 36047051900
# 42071000100
# 36055009301
# 29510125500
# censusgeocode error
# 17031040900
# 55079014400
# censusgeocode error
# 55117011400
# censusgeocode error
# 36055012700
# 47037019500
# censusgeocode error
# censusgeocode error
# 08031003703
# 53033007500
# 41051003402
# 06075060700
# 47037019500
# 39049000600
# 36055009302
# 25017353101
# 25017353101
# censusgeocode error
# 10005051102
# 42095011300
# 40109103602
# 48113020400
# 48453001100
# 04005001200
# censusgeocode error
# 36061004200
# 06075016900
# 06001422900
# censusgeocode error
# 26081004400
# 36047055500
# 25017353700
# censusgeocode error
# 36103123500
# 51760030500
# 13121001400
# 51810044004
# 42101015800
# 26163521400
# 17031831100
# 27053107500
# 31055003600
# 08031003203
# censusgeocode error
# censusgeocode error
# 11001004400
# 42003427000
# 06075016400
# 06075040100
# censusgeocode error
# 06059074106
# 36061003602
# censusgeocode error
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 34025806000
# 36061014900
# 25017351100
# censusgeocode error
# 41051001000
# 06075012202
# censusgeocode error
# 06073017304
# censusgeocode error
# censusgeocode error
# 36061006800
# 51630000100
# censusgeocode error
# 25025000802
# 09003502500
# censusgeocode error
# 55079008000
# 25017353101
# censusgeocode error
# 26163517500
# 17031841300
# 42003481000
# 36061006500
# 41051002100
# 53033008100
# 36047044900
# 17031843100
# 17031833000
# 06037231220
# 06037226002
# 06059088701
# 06037206031
# 06037195500
# 06037139401
# censusgeocode error
# censusgeocode error
# 48453001100
# censusgeocode error
# 53033004700
# censusgeocode error
# 167
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.659
# Model:                            OLS   Adj. R-squared (uncentered):              0.653
# Method:                 Least Squares   F-statistic:                              105.7
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    3.90e-38
# Time:                        15:26:50   Log-Likelihood:                         -244.30
# No. Observations:                 167   AIC:                                      494.6
# Df Residuals:                     164   BIC:                                      504.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.7555      0.399      1.894      0.060      -0.032       1.543
# x2             0.0351      0.004      8.766      0.000       0.027       0.043
# x3          1.377e-09   1.59e-09      0.866      0.388   -1.76e-09    4.52e-09
# ==============================================================================
# Omnibus:                      101.682   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.133
# Skew:                           2.392   Prob(JB):                    7.45e-106
# Kurtosis:                       9.832   Cond. No.                     2.52e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.52e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['Air Traffic Controller', 'Big Thief', 'J and The 9s', 'Charly Bliss', 'Hop Along'], followers = 50000)

# plot_all_tours(tours)

# %%
# optimal_path(tours)

# %% [markdown]
# ## Midwest
#
# (https://gooddeedseats.com/45-up-and-coming-rock-bands/)
# (https://radiomilwaukee.org/discover-music/tapd-in/wisconsin-bands-to-watch-in-2019/)

# %%
tract_stats(names = ['Hemmingbirds', 'The Accidentals', 'The Cactus Blossoms', 'Chicken Wire Empire', 'Rodeo Ruby Love'], followers = 50000, demo='non-white')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 1
# 1
# related_artists search 1
# related_artists ra_help 3
# 105
# 55
# related_artists search 1
# related_artists ra_help 3
# 108
# 64
# related_artists search 1
# related_artists ra_help 3
# 118
# 48
# related_artists search 1
# related_artists ra_help 3
# 103
# 41
# 34023007103
# 36029016500
# 25025000704
# 17031081600
# 34001001300
# 06037208502
# 06073002201
# 04013113100
# 04005001200
# 08041006700
# 08031001600
# 08069000100
# 49035114000
# 36047049900
# 17031051100
# 06075022702
# 06037181000
# 36047055500
# 25027731700
# 06001431000
# 48091310503
# 48201411000
# 48113004600
# 56001963400
# censusgeocode error
# 17031310600
# 39035107701
# 51760030500
# 42101036900
# 11001004400
# 17031809900
# 26161400100
# 45045002504
# censusgeocode error
# 17019011100
# 27169670400
# 55123960400
# 19103002100
# 25017353000
# 25017353101
# 25013813207
# 25013810901
# 08067971100
# 55087010100
# 16001000100
# 41029002000
# censusgeocode error
# 53063003500
# 30067000200
# censusgeocode error
# 55103970100
# 06001402800
# 06075016400
# censusgeocode error
# 51760030200
# censusgeocode error
# 26077000201
# 39049003200
# 42101000401
# 36061006800
# 36029016500
# 26081002000
# 08067971100
# 26125142200
# 45063020300
# 45045002303
# 37089930701
# 37063002200
# censusgeocode error
# 42017102500
# 36047055700
# 09005425600
# 36001001100
# censusgeocode error
# 36059301200
# 42133000100
# 51087200105
# 42101037600
# 06059042313
# 09009165400
# 25013811400
# 25025010405
# 42101002400
# censusgeocode error
# 27137001900
# 27123032100
# censusgeocode error
# 27099000410
# 29510105198
# 48053960400
# 53063003600
# 53033005301
# censusgeocode error
# 41017001400
# censusgeocode error
# 18105000100
# censusgeocode error
# 27053104400
# censusgeocode error
# 29510119300
# 21111004900
# 06023001000
# 06075018000
# 06041101200
# 06037195500
# censusgeocode error
# 27053104800
# censusgeocode error
# censusgeocode error
# 13121003500
# censusgeocode error
# 36061006200
# 32003000700
# 08031003701
# 34037374600
# 17031070200
# 55073001500
# 39049000600
# censusgeocode error
# 36061003001
# 11001000100
# censusgeocode error
# 23009965503
# censusgeocode error
# 06075015900
# 06073017304
# censusgeocode error
# 25019950200
# 23005000500
# 08031004405
# 08069000100
# 08101003500
# 25003935300
# 33013032300
# 50025968600
# censusgeocode error
# censusgeocode error
# censusgeocode error
# censusgeocode error
# 04005001200
# 06037215101
# 06059042201
# censusgeocode error
# 37063002200
# censusgeocode error
# censusgeocode error
# 21111008100
# censusgeocode error
# 27053103900
# 26081002600
# 48201210100
# censusgeocode error
# 40143003200
# 05143011300
# 28049002700
# 06037212900
# 36061024000
# 36047038900
# 17031221500
# 26163517200
# 42017104303
# 42101021400
# censusgeocode error
# 06113011300
# 06029001600
# 36061003700
# 22033001600
# 18097355900
# censusgeocode error
# 55111000800
# 17113001700
# 37119000700
# 37135010705
# 51540001000
# 09009165400
# censusgeocode error
# 36061004200
# 36109000700
# 36061014900
# 25017350900
# 06075012000
# 26125173100
# 17031050600
# 27053108800
# censusgeocode error
# 37135010705
# 37119001400
# 37021000100
# 08031001402
# 08069000100
# 41051001000
# censusgeocode error
# 06037700501
# 28071950202
# 11001010200
# 36029013800
# 39035141100
# censusgeocode error
# 48201510200
# 39035117202
# 36047051900
# 34025807003
# 42071000100
# 37021001600
# 22071007700
# 28071950202
# 29095015500
# 21117067000
# 39035117202
# 36047055700
# 162
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.768
# Model:                            OLS   Adj. R-squared (uncentered):              0.764
# Method:                 Least Squares   F-statistic:                              175.7
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    2.91e-50
# Time:                        15:50:26   Log-Likelihood:                         -167.07
# No. Observations:                 162   AIC:                                      340.1
# Df Residuals:                     159   BIC:                                      349.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.8378      0.243      3.446      0.001       0.358       1.318
# x2             0.0276      0.002     11.838      0.000       0.023       0.032
# x3          1.393e-09   1.04e-09      1.342      0.182   -6.57e-10    3.44e-09
# ==============================================================================
# Omnibus:                       91.312   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              383.242
# Skew:                           2.216   Prob(JB):                     6.03e-84
# Kurtosis:                       9.093   Cond. No.                     2.37e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.37e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['Hemmingbirds', 'The Accidentals', 'The Cactus Blossoms', 'Chicken Wire Empire', 'Rodeo Ruby Love'], followers = 50000)

# plot_all_tours(tours)

# %%
# optimal_path(tours)

# %% [markdown]
# ## South
#
# (https://gooddeedseats.com/45-up-and-coming-rock-bands/)
# (https://www.pastemagazine.com/blogs/lists/2013/08/12-virginia-bands-you-should-listen-to-now.html)
# (https://clture.org/10-carolina-bands/)

# %%
tract_stats(names = ['Savoy Motel', 'Ringo Deathstarr', 'Gull', 'Shadowgraphs', 'Young Mister'], followers = 50000, demo='non-white')
# Out:
# yo
# related_artists search 1
# related_artists ra_help 3
# 109
# 74
# related_artists search 1
# related_artists ra_help 3
# 119
# 30
# related_artists search 1
# related_artists ra_help 3
# 0
# 0
# related_artists search 1
# related_artists ra_help 3
# 108
# 71
# related_artists search 1
# related_artists ra_help 3
# 93
# 49
# 41051001101
# 06001983200
# 41051003402
# 41051001301
# 41051004200
# 53033009200
# 41051002100
# 53067010520
# 05143011300
# censusgeocode error
# 39061001000
# 36029016500
# censusgeocode error
# censusgeocode error
# 42101014200
# 53033004700
# 41051005100
# censusgeocode error
# censusgeocode error
# 06059074106
# censusgeocode error
# censusgeocode error
# 26081002000
# censusgeocode error
# 26125173500
# 06037209300
# censusgeocode error
# 53033010300
# censusgeocode error
# censusgeocode error
# 17031833000
# censusgeocode error
# 16001000100
# censusgeocode error
# censusgeocode error
# 48453001100
# 22071011100
# 29095016800
# 27053006800
# 55025001900
# censusgeocode error
# 36047057900
# 42101002400
# 34025807003
# 47037019500
# 47037019500
# 37119001400
# 37135010705
# censusgeocode error
# censusgeocode error
# 06073002201
# 06037197500
# 06067001300
# 36061001800
# 36047054900
# 42101037900
# 53033007500
# 41051002100
# 06075022702
# 06073009202
# 06065044522
# 06065042800
# 06067001300
# 53033007100
# 06075060700
# censusgeocode error
# 06075016200
# 06037206031
# 06037700300
# censusgeocode error
# 48201210400
# 06037191820
# 42101014400
# 39035161700
# 17031242400
# 26163517200
# 41051003401
# 06037195100
# 01073004500
# 47157001600
# 04013114100
# 06073005300
# 06037190700
# 06087101000
# 06075018000
# 06037224010
# 06075015900
# 53033008100
# 41051002203
# 04013113100
# censusgeocode error
# 53033007500
# censusgeocode error
# 06037183810
# 17031310600
# 26163517500
# 06087101000
# 06079011102
# 06073017304
# censusgeocode error
# 06037194402
# 06071010420
# censusgeocode error
# 32003000700
# 29095015800
# 29510124200
# 47037019200
# 13089020900
# 11001001402
# 25017352700
# 32003000700
# 48453001100
# 48453001100
# 17031831100
# 36047055700
# 25025000703
# 24510120500
# 42101037600
# 37119000700
# 21111005900
# 47179060100
# 37183050100
# censusgeocode error
# 45013002107
# 37149920304
# 45045002303
# 48453001100
# 48453001100
# 06037226002
# 06073004400
# 04019000100
# 48141001700
# 48453000902
# 48113020400
# 11001003500
# 06037700400
# 06075017802
# 41051002000
# 17031051100
# 26077000201
# 17031241400
# 06075025300
# censusgeocode error
# 26077000202
# 06037207900
# 36081053500
# 39035160602
# 26163517500
# 17031220602
# 06037207302
# 53033008001
# 34029715302
# censusgeocode error
# 04019000400
# 22071013500
# 13089020900
# 37063002200
# 11001004400
# 42101015800
# 11001004400
# 36061005700
# 42101000401
# 11001008402
# 32003006700
# 04013114100
# 35049001202
# 06075017601
# 06037700501
# 25017353101
# 36061006500
# censusgeocode error
# 17031070300
# censusgeocode error
# 51760020500
# censusgeocode error
# 11001003800
# censusgeocode error
# 08031001600
# censusgeocode error
# 51710002800
# 25017353700
# 42101037600
# 36047049900
# 09009165400
# 24510120600
# 51760041300
# 37063002200
# 140
# 5
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.670
# Model:                            OLS   Adj. R-squared (uncentered):              0.663
# Method:                 Least Squares   F-statistic:                              92.69
# Date:                Tue, 10 Dec 2019   Prob (F-statistic):                    8.13e-33
# Time:                        16:01:03   Log-Likelihood:                         -195.24
# No. Observations:                 140   AIC:                                      396.5
# Df Residuals:                     137   BIC:                                      405.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6628      0.410      1.615      0.109      -0.149       1.475
# x2             0.0259      0.007      3.885      0.000       0.013       0.039
# x3          4.019e-06   2.47e-06      1.626      0.106   -8.68e-07    8.91e-06
# ==============================================================================
# Omnibus:                      112.465   Durbin-Watson:                   2.267
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              916.725
# Skew:                           2.940   Prob(JB):                    8.62e-200
# Kurtosis:                      14.072   Cond. No.                     3.52e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.52e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
tours = compile_tours(names = ['Savoy Motel', 'Ringo Deathstarr', 'Gull', 'Shadowgraphs', 'Young Mister'], followers = 50000)

# plot_all_tours(tours)

# %%
# optimal_path(tours)
