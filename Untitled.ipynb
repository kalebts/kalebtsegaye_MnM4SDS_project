# %%
import geopandas as gpd
import pandas as pd
# import flask
import matplotlib.pyplot as plt

cities = gpd.read_file('../lectures/data/cities.geojson')
countries = gpd.read_file('../lectures/data/countries.gpkg')
print(cities)

df = pd.DataFrame(
    {'City': ['A', 'B', 'C', 'D', 'E'],
     'Country': ['UK', 'UK', 'UK', 'UK', 'UK'],
     'Latitude': [-9.25, -9.20, -9.00, -8.70, -8.50],
     'Longitude': [51.75, 52.50, 52.1, 51.8, 51.9],
     'geometry': ["POINT (-57.84000247340134 -34.47999900541754)", "POINT (-57.84000247340134 -34.47999900541754)",
                 "POINT (-57.84000247340134 -34.47999900541754)",
                 "POINT (-57.84000247340134 -34.47999900541754)",
                 "POINT (-57.84000247340134 -34.47999900541754)"]})
        
cit2 = gpd.GeoDataFrame( df)

i = 0
for c in cities["longitude"]:
    if (c <= 53 and c <= 50):
        cit2 = cities.loc[i]
    i+= 1
    
country = countries.loc[[78]]

print(cit2)

        
fig, ax = plt.subplots(figsize=(12,12))
ax.set_xlim(-10, -8)
ax.set_ylim(51, 53)
country.plot(ax=ax)
cit2.plot(color = "red", ax=ax)
plt.tight_layout()
plt.savefig('cities_p2.png')
plt.show()
# Out:
#                         name  worldcity  megacity   latitude   longitude  \
# 0     Colonia del Sacramento        0.0         0 -34.479999  -57.840002
# 1                   Trinidad        0.0         0 -33.543999  -56.900997
# 2                Fray Bentos        0.0         0 -33.138999  -58.303997
# 3                  Canelones        0.0         0 -34.538004  -56.284001
# 4                    Florida        0.0         0 -34.099002  -56.214998
# ...                      ...        ...       ...        ...         ...
# 7338          Rio de Janeiro        1.0         1 -22.925023  -43.225021
# 7339               São Paulo        1.0         1 -23.558680  -46.625020
# 7340                  Sydney        1.0         1 -33.920011  151.185180
# 7341               Singapore        1.0         1   1.293033  103.855821
# 7342               Hong Kong        1.0         1  22.304981  114.185009
#
#        pop_max   pop_min  pop_other  \
# 0        21714     21714          0
# ...
